# %%
# !pip install xgboost

# %%
import pandas as pd
import numpy as np
import os


import xgboost as xgb
from xgboost import XGBClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,  confusion_matrix,accuracy_score, precision_score , recall_score , f1_score

# %%
df = pd.read_csv("C:/Users/farim/DSI_Team_Project_Bank_Marketing/data/processed/df_processed.csv")

#df = pd.read_csv(
    #"C:/Users/farim/DSI_Team_Project_Bank_Marketing/data/processed/df_processed.csv",
   # encoding="ISO-8859-1")

# %%
df.shape
# Out:
# (45211, 40)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  45211 non-null  float64
#  1   balance              45211 non-null  float64
#  2   day                  45211 non-null  float64
#  3   duration             45211 non-null  float64
#  4   campaign             45211 non-null  float64
#  5   pdays                45211 non-null  float64
#  6   previous             45211 non-null  float64
#  7   y                    45211 non-null  int64
#  8   job_blue-collar      45211 non-null  int64
#  9   job_entrepreneur     45211 non-null  int64
#  10  job_housemaid        45211 non-null  int64
#  11  job_management       45211 non-null  int64
#  12  job_retired          45211 non-null  int64
#  13  job_self-employed    45211 non-null  int64
#  14  job_services         45211 non-null  int64
# ...

# %%
X=df.drop(['y'],axis=1)
Y = df['y']

# %%
# Count the number of positive and negative samples
num_negatives = sum(Y == 0)
num_positives = sum(Y == 1)

# Calculate scale_pos_weight
scale_pos_weight = num_negatives / num_positives
print("scale_pos_weight:", scale_pos_weight)
# Out:
# scale_pos_weight: 7.548118737001324

# %%
# split data into train and test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Display the shapes of the resulting datasets
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"Y_train shape: {Y_train.shape}")
print(f"Y_test shape: {Y_test.shape}")
# Out:
# X_train shape: (36168, 39)
# X_test shape: (9043, 39)
# Y_train shape: (36168,)
# Y_test shape: (9043,)

# %%
# Initialize the XGBoost classifier with scale_pos_weight
xgb_model = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    use_label_encoder=False,
    scale_pos_weight=scale_pos_weight,  # Adjust for class imbalance
    random_state=42
)

# Train the model
xgb_model.fit(X_train, Y_train)
# Out:
# c:\Users\farim\miniconda3\envs\dsi_participant\lib\site-packages\xgboost\core.py:158: UserWarning: [19:44:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
# ...

# %%
# Make predictions
Y_pred_xgb = xgb_model.predict(X_test)
#Y_pred_proba = xgb_model.predict_proba(X_test)[:, 1]  # Probabilities for ROC-AUC

# %%
# Calculate the confusion matrix
conf_matrix = confusion_matrix(Y_test, Y_pred_xgb)

# Generate the classification report
class_report = classification_report(Y_test, Y_pred_xgb)


# evaluation metrics
accuracy_xgb = accuracy_score(Y_test, Y_pred_xgb)
precision_xgb = precision_score(Y_test, Y_pred_xgb, average='binary')
recall_xgb = recall_score(Y_test, Y_pred_xgb, average='binary')
f1_xgb = f1_score(Y_test, Y_pred_xgb, average='binary')
# Out:
# Confusion Matrix:
# [[6998  954]
#  [ 227  864]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92      7952
#            1       0.48      0.79      0.59      1091
#
#     accuracy                           0.87      9043
#    macro avg       0.72      0.84      0.76      9043
# weighted avg       0.91      0.87      0.88      9043
#
#
# Accuracy:
# 0.8694017472077851

# %%
print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
#print("\nAccuracy:")
#print(accuracy_xgb)

print(f"Accuracy (XGBoost): {accuracy_xgb:.2f}")
print(f"Precision (XGBoost): {precision_xgb:.2f}")
print(f"Recall (XGBoost): {recall_xgb:.2f}")
print(f"F1-Score (XGBoost): {f1_xgb:.2f}")
# Out:
# Confusion Matrix:
# [[6998  954]
#  [ 227  864]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92      7952
#            1       0.48      0.79      0.59      1091
#
#     accuracy                           0.87      9043
#    macro avg       0.72      0.84      0.76      9043
# weighted avg       0.91      0.87      0.88      9043
#
# Accuracy (XGBoost): 0.87
# Precision (XGBoost): 0.48
# Recall (XGBoost): 0.79
# F1-Score (XGBoost): 0.59
